# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import lightgbm as lgb

# %% [markdown]
# # df=pd.read_csv("fleet_train_imputed.csv")
# df.head(50)

# %%
df.isnull().sum()
# Out:
# Maintenance_flag             0
# record_id                    0
# Measurement_timestamp        0
# Vehicle_speed_sensor         0
# Vibration                    0
# Engine_Load                  0
# Engine_Coolant_Temp          0
# Intake_Manifold_Pressure     0
# Engine_RPM                   0
# Speed_OBD                    0
# Intake_Air_Temp              0
# Mass_Air_Flow_Rate           0
# Throttle_Pos_Manifold        0
# Voltage_Control_Module       0
# Ambient_air_temp             0
# Accel_Pedal_Pos_D            0
# Engine_Oil_Temp              0
# Speed_GPS                    0
# GPS_Longitude                0
# GPS_Latitude                 0
# GPS_Bearing                  0
# GPS_Altitude                 0
# Turbo_Boost_And_Vcm_Gauge    0
# Trip_Distance                0
# Litres_Per_100km_Inst        0
# Accel_Ssor_Total             0
# CO2_in_g_per_km_Inst         0
# Trip_Time_journey            0
# fleetid                      0
# truckid                      0
# Region                       0
# dtype: int64

# %%
df.drop(['record_id','fleetid','truckid','Region','Measurement_timestamp'], axis=1, inplace=True)

# %%
features_to_normalize = [
    'Engine_Load', 'Engine_RPM', 'Engine_Coolant_Temp', 'Vibration',
    'Mass_Air_Flow_Rate', 'Engine_Oil_Temp', 'Throttle_Pos_Manifold',
    'Accel_Ssor_Total', 'Trip_Distance', 'Trip_Time_journey', 'Turbo_Boost_And_Vcm_Gauge'
]

# %%
scaler = MinMaxScaler()
df[features_to_normalize] = scaler.fit_transform(df[features_to_normalize])

# df['engine_health_score'] = (df['Engine_Load'] + df['Engine_RPM'] + df['Engine_Coolant_Temp']) / 3
# df['battery_health_score'] = (df['Mass_Air_Flow_Rate'] + df['Engine_Oil_Temp']) / 2
# df['vibration_score'] = df['Vibration']
df.head(50)
# Out:
#     Maintenance_flag  Vehicle_speed_sensor  Vibration  Engine_Load  \
# 0                  0                    35   0.811828     0.213439
# 1                  0                   142   0.236559     0.201581
# 2                  0                   128   0.311828     0.434783
# 3                  0                   117   0.370968     1.000000
# 4                  0                    98   0.473118     0.735178
# 5                  0                    96   0.483871     0.435615
# 6                  0                    55   0.704301     0.395257
# 7                  0                    58   0.688172     0.387352
# 8                  0                   114   0.387097     0.138340
# 9                  0                   157   0.155914     0.541502
# 10                 0                    34   0.817204     0.284585
# 11                 0                   124   0.333333     0.588933
# 12                 0                    84   0.548387     0.435615
# 13                 0                    18   0.903226     0.501976
# 14                 0                    90   0.516129     0.154150
# 15                 0                    95   0.489247     0.533597
# 16                 0                   114   0.387097     0.490119
# 17                 0                   114   0.387097     0.114625
# 18                 0                   159   0.145161     0.435615
# 19                 0                   109   0.413978     0.478261
# 20                 0                    36   0.806452     0.264822
# 21                 0                   104   0.440860     0.035573
# 22                 0                    88   0.526882     0.435615
# 23                 0                    28   0.849462     0.130435
# 24                 0                   113   0.392473     0.553360
# 25                 0                    55   0.704301     0.288538
# 26                 0                   118   0.365591     0.537549
# 27                 0                    21   0.887097     0.209486
# 28                 0                   128   0.311828     0.075099
# 29                 0                   105   0.435484     0.616601
# 43               7.622250          0.639065            201.608370
# 44               4.277167          0.627333            113.130980
# 45               3.592261          0.696569             95.015240
# 46               4.753049          0.537054            116.734042
# 47               4.753049          0.589838             20.169476
# 48               2.423520          0.563671             64.102060
# 49               5.542250          0.684031            146.592400
#
#     Trip_Time_journey
# 0            0.986216
# 1            0.111591
# 2            0.100084
# 3            0.068201
# 4            0.850653
# 5            0.590795
# 6            0.893923
# 7            0.014383
# 8            0.430660
# 9            0.116864
# 10           0.988613
# 11           0.432938
# 12           0.057413
# 13           0.918255
# 14           0.579648
# 15           0.603020
# 16           0.137600
# 17           0.555915
# 18           0.727316
# 19           0.646410
# 20           0.986576
# 21           0.497423
# 22           0.052020
# 23           0.903392
# 24           0.623637
# 25           0.893683
# 26           0.641136
# 27           0.924368
# 28           0.088577
# 29           0.852451
# 30           0.635982
# 31           0.937792
# 32           0.504495
# 33           0.949658
# 34           0.580007
# 35           0.471293
# 36           0.948100
# 37           0.594271
# 38           0.383795
# 39           0.056335
# 40           0.437253
# 41           0.052140
# 42           0.049982
# 43           0.994726
# 44           0.983459
# 45           0.513604
# 46           0.387870
# 47           0.054537
# 48           0.610092
# 49           0.898118
#
# [50 rows x 26 columns]

# %%
def calculate_condition_score(row):
    engine_health_score = (row['Engine_Load'] + row['Engine_RPM'] + row['Engine_Coolant_Temp']) / 3
    usage_severity = row['Engine_Load'] * (row['Trip_Distance'] + row['Trip_Time_journey'])
    anomaly_flag = ((row['Vibration'] > 0.7) | (row['Engine_Coolant_Temp'] > 0.8)).astype(int)
    condition_score = 0.5 * engine_health_score + 0.3 * usage_severity + 0.2 * anomaly_flag
    return condition_score

df['Condition_Score'] = df.apply(calculate_condition_score, axis=1)

df.head()
# Out:
#    Maintenance_flag  Vehicle_speed_sensor  Vibration  Engine_Load  \
# 0                 0                    35   0.811828     0.213439
# 1                 0                   142   0.236559     0.201581
# 2                 0                   128   0.311828     0.434783
# 3                 0                   117   0.370968     1.000000
# 4                 0                    98   0.473118     0.735178
#
#    Engine_Coolant_Temp  Intake_Manifold_Pressure  Engine_RPM  Speed_OBD  \
# 0             0.600000                       116    0.231587         35
# 1             0.600000                       135    0.577541        142
# 2             0.133333                       109    0.476660        128
# 3             0.666667                       128    0.638226        117
# 4             0.666667                       123    0.291234         98
#
#    Intake_Air_Temp  Mass_Air_Flow_Rate  ...  GPS_Latitude  GPS_Bearing  \
# 0               10            0.111290  ...     48.932757         75.2
# 1               16            0.263722  ...     48.494790        274.4
# 2                9            0.189380  ...     48.479574        257.1
# 3               13            0.277822  ...     48.611216        330.7
# 4                9            0.140741  ...     48.377976          3.0
#
#    GPS_Altitude  Turbo_Boost_And_Vcm_Gauge  Trip_Distance  \
# 0           164                   0.091503       0.993639
# 1           436                   0.215686       0.144925
# 2           508                   0.045752       0.129077
# 3           618                   0.169935       0.075531
# 4           154                   0.137255       0.912552
#
#    Litres_Per_100km_Inst  Accel_Ssor_Total  CO2_in_g_per_km_Inst  \
# 0               2.351502          0.653445             62.197178
# 1               1.244649          0.651602             32.920940
# 2               2.124100          0.676852             56.182410
# 3               4.753049          0.665256            116.734042
# 4               4.031921          0.598824            106.644250
#
#    Trip_Time_journey  Condition_Score
# 0           0.986216         0.500944
# 1           0.111591         0.245366
# 2           0.100084         0.204020
# 3           0.068201         0.427268
# 4           0.850653         0.671061
#
# [5 rows x 27 columns]

# %%
def assign_priority(score):
    if score > 0.70:
        return 'Critical'
    elif score > 0.45:
        return 'Moderate'
    else:
        return 'Low'

# %%
df['Priority'] = df['Condition_Score'].apply(assign_priority)
df.to_csv('fleet_train_priorities.csv', index=False)
df.head(50)
# Out:
#     Maintenance_flag  Vehicle_speed_sensor  Vibration  Engine_Load  \
# 0                  0                    35   0.811828     0.213439
# 1                  0                   142   0.236559     0.201581
# 2                  0                   128   0.311828     0.434783
# 3                  0                   117   0.370968     1.000000
# 4                  0                    98   0.473118     0.735178
# 5                  0                    96   0.483871     0.435615
# 6                  0                    55   0.704301     0.395257
# 7                  0                    58   0.688172     0.387352
# 8                  0                   114   0.387097     0.138340
# 9                  0                   157   0.155914     0.541502
# 10                 0                    34   0.817204     0.284585
# 11                 0                   124   0.333333     0.588933
# 12                 0                    84   0.548387     0.435615
# 13                 0                    18   0.903226     0.501976
# 14                 0                    90   0.516129     0.154150
# 15                 0                    95   0.489247     0.533597
# 16                 0                   114   0.387097     0.490119
# 17                 0                   114   0.387097     0.114625
# 18                 0                   159   0.145161     0.435615
# 19                 0                   109   0.413978     0.478261
# 20                 0                    36   0.806452     0.264822
# 21                 0                   104   0.440860     0.035573
# 22                 0                    88   0.526882     0.435615
# 23                 0                    28   0.849462     0.130435
# 24                 0                   113   0.392473     0.553360
# 25                 0                    55   0.704301     0.288538
# 26                 0                   118   0.365591     0.537549
# 27                 0                    21   0.887097     0.209486
# 28                 0                   128   0.311828     0.075099
# 29                 0                   105   0.435484     0.616601
# 30                 0                   113   0.392473     0.490119
# 31                 0                    36   0.806452     0.324111
# 32                 0                    87   0.532258     0.418972
# 33                 0                    22   0.881720     0.225296
# 34                 0                    94   0.494624     1.000000
# 35                 0                   111   0.403226     0.435615
# 36                 0                    42   0.774194     0.201581
# 37                 0                    96   0.483871     0.640316
# 38                 0                   100   0.462366     0.090909
# 39                 0                    90   0.516129     0.435615
# 40                 0                   122   0.344086     0.435615
# 41                 0                    88   0.526882     0.435615
# 42                 0                    76   0.591398     0.435615
# 43                 0                    36   0.806452     0.296443
# 44                 0                    34   0.817204     0.221344
# 45                 0                   106   0.430108     0.640316
# 46                 0                    99   0.467742     0.000000
# 47                 0                    83   0.553763     0.435615
# 48                 0                    96   0.483871     0.474308
# 49                 0                    78   0.580645     0.482213
#
#     Engine_Coolant_Temp  Intake_Manifold_Pressure  Engine_RPM  Speed_OBD  \
# 0              0.600000                       116    0.231587         35
# 1              0.600000                       135    0.577541        142
# 2              0.133333                       109    0.476660        128
# 3              0.666667                       128    0.638226        117
# 4              0.666667                       123    0.291234         98
# 5              0.266667                       115    0.262448         96
# 6              0.533333                       110    0.339730         55
# 7              0.600000                       105    0.384595         58
rows x 28 columns]

# %%
df.isnull().sum()
# Out:
# Maintenance_flag             0
# Vehicle_speed_sensor         0
# Vibration                    0
# Engine_Load                  0
# Engine_Coolant_Temp          0
# Intake_Manifold_Pressure     0
# Engine_RPM                   0
# Speed_OBD                    0
# Intake_Air_Temp              0
# Mass_Air_Flow_Rate           0
# Throttle_Pos_Manifold        0
# Voltage_Control_Module       0
# Ambient_air_temp             0
# Accel_Pedal_Pos_D            0
# Engine_Oil_Temp              0
# Speed_GPS                    0
# GPS_Longitude                0
# GPS_Latitude                 0
# GPS_Bearing                  0
# GPS_Altitude                 0
# Turbo_Boost_And_Vcm_Gauge    0
# Trip_Distance                0
# Litres_Per_100km_Inst        0
# Accel_Ssor_Total             0
# CO2_in_g_per_km_Inst         0
# Trip_Time_journey            0
# Condition_Score              0
# Priority                     0
# dtype: int64

# %%
def calc_risk(df):
    
    df['Overstrain_Risk'] = 0.5 * df['Engine_Load'] + 0.5 * df['Engine_RPM']
    df['Heat_Dissipation_Risk'] = 0.4 * df['Engine_Coolant_Temp'] + 0.6 * df['Engine_Oil_Temp']
    df['Power_Failure_Risk'] = 0.5 * df['Mass_Air_Flow_Rate'] + 0.5 * df['Turbo_Boost_And_Vcm_Gauge']

calc_risk(df)
def assign_failure_label(row):
    if row['Condition_Score'] < 0.3:
        return 'No Failure'
    else:
        risks = {
            'Overstrain Failure': row['Overstrain_Risk'],
            'Heat Dissipation Failure': row['Heat_Dissipation_Risk'],
            'Power Failure': row['Power_Failure_Risk']
        }
        return max(risks, key=risks.get)

df['Failure_Type'] = df.apply(assign_failure_label, axis=1)

df['Failure_Type'].value_counts()
# Out:
# Failure_Type
# Heat Dissipation Failure    4556
# No Failure                  1814
# Overstrain Failure          1103
# Power Failure                 31
# Name: count, dtype: int64

# %%
df[[
    'Engine_Load', 'Engine_RPM', 'Engine_Coolant_Temp', 'Vibration',
    'Mass_Air_Flow_Rate', 'Engine_Oil_Temp', 'Throttle_Pos_Manifold',
    'Accel_Ssor_Total', 'Trip_Distance', 'Trip_Time_journey']]
# Out:
#       Engine_Load  Engine_RPM  Engine_Coolant_Temp  Vibration  \
# 0        0.213439    0.231587             0.600000   0.811828
# 1        0.201581    0.577541             0.600000   0.236559
# 2        0.434783    0.476660             0.133333   0.311828
# 3        1.000000    0.638226             0.666667   0.370968
# 4        0.735178    0.291234             0.666667   0.473118
# ...           ...         ...                  ...        ...
# 7499     0.169960    0.326245             0.666667   0.543011
# 7500     0.435615    0.253890             0.733333   0.489247
# 7501     0.557312    0.470176             0.666667   0.645161
# 7502     0.462451    0.385373             0.533333   0.596774
# 7503     0.628459    0.443724             0.600000   0.741935
#
#       Mass_Air_Flow_Rate  Engine_Oil_Temp  Throttle_Pos_Manifold  \
# 0               0.111290         0.500000               0.977941
# 1               0.263722         0.500000               0.977941
# 2               0.189380         0.071429               0.977941
# 3               0.277822         0.642857               0.977941
# 4               0.140741         0.500000               0.977941
# ...                  ...              ...                    ...
# 7499            0.144221         0.642857               0.970588
# 7500            0.136546         0.714286               0.977941
# 7501            0.216867         0.571429               0.779412
# 7502            0.162874         0.357143               0.977941
# 7503            0.232218         0.357143               0.977941
#
#       Accel_Ssor_Total  Trip_Distance  Trip_Time_journey
# 0             0.653445       0.993639           0.986216
# 1             0.651602       0.144925           0.111591
# 2             0.676852       0.129077           0.100084
# 3             0.665256       0.075531           0.068201
# 4             0.598824       0.912552           0.850653
# ...                ...            ...                ...
# 7499          0.564160       0.339978           0.357905
# 7500          0.558672       0.223546           0.222462
# 7501          0.627092       0.883545           0.827760
# 7502          0.534757       0.775144           0.699389
# 7503          0.616680       0.880722           0.823325
#
# [7504 rows x 10 columns]

# %%
df
# Out:
#       Maintenance_flag  Vehicle_speed_sensor  Vibration  Engine_Load  \
# 0                    0                    35   0.811828     0.213439
# 1                    0                   142   0.236559     0.201581
# 2                    0                   128   0.311828     0.434783
# 3                    0                   117   0.370968     1.000000
# 4                    0                    98   0.473118     0.735178
# ...                ...                   ...        ...          ...
# 7499                 1                    85   0.543011     0.169960
# 7500                 0                    95   0.489247     0.435615
# 7501                 1                    66   0.645161     0.557312
# 7502                 1                    75   0.596774     0.462451
# 7503                 1                    48   0.741935     0.628459
#
#       Engine_Coolant_Temp  Intake_Manifold_Pressure  Engine_RPM  Speed_OBD  \
# 0                0.600000                       116    0.231587         35
# 1                0.600000                       135    0.577541        142
# 2                0.133333                       109    0.476660        128
# 3                0.666667                       128    0.638226        117
# 4                0.666667                       123    0.291234         98
# ...                   ...                       ...         ...        ...
# 7499             0.666667                       106    0.326245         85
# 7500             0.733333                       109    0.253890         95
# 7501             0.666667                       126    0.470176         66
# 7502             0.533333                       109    0.385373         75
# 7503             0.600000                       133    0.443724         48
#
#       Intake_Air_Temp  Mass_Air_Flow_Rate  ...  Litres_Per_100km_Inst  \
# 0                  10            0.111290  ...               2.351502
# 1                  16            0.263722  ...               1.244649
# 2                   9            0.189380  ...               2.124100
# 3                  13            0.277822  ...               4.753049
# 4                   9            0.140741  ...               4.031921
# ...               ...                 ...  ...                    ...
# 7499               10            0.144221  ...               2.500408
# 7500               12            0.136546  ...               4.753049
# 7501               13            0.216867  ...               6.450333
# 7502                8            0.162874  ...               3.525263
# 7503               16            0.232218  ...              10.294817
#
#       Accel_Ssor_Total  CO2_in_g_per_km_Inst  Trip_Time_journey  \
# 0             0.653445             62.197178           0.986216
# 1             0.651602             32.920940           0.111591
# 2             0.676852             56.182410           0.100084
# 3             0.665256            116.734042           0.068201
# 4             0.598824            106.644250           0.850653
# ...                ...                   ...                ...
# 7499          0.564160             66.135735           0.357905
# 7500          0.558672            116.734042           0.222462
# 7501          0.627092            170.611180           0.827760
# 7502          0.534757             93.243150           0.699389
# 7503          0.616680            272.297730           0.823325
#
#       Condition_Score  Priority  Overstrain_Risk  Heat_Dissipation_Risk  \
# 0            0.500944  Moderate         0.222513               0.540000
# 1            0.245366       Low         0.389561               0.540000
# 2            0.204020       Low         0.455721               0.096190
# 3            0.427268       Low         0.819113               0.652381
# 4            0.671061  Moderate         0.513206               0.566667
# ...               ...       ...              ...                    ...
# 7499         0.229396       Low         0.248103               0.652381
# 7500         0.295426       Low         0.344752               0.721905
# 7501         0.568479  Moderate         0.513744               0.609524
# 7502         0.434762       Low         0.423912               0.427619
# 7503         0.799974  Critical         0.536091               0.454286
#
#       Power_Failure_Risk              Failure_Type
# 0               0.101396  Heat Dissipation Failure
# 1               0.239704                No Failure
# 2               0.117566                No Failure
# 3               0.223879        Overstrain Failure
# 4               0.138998  Heat Dissipation Failure
# ...                  ...                       ...
# 7499            0.085183                No Failure
# 7500            0.091149                No Failure
# 7501            0.186865  Heat Dissipation Failure
# 7502            0.104313  Heat Dissipation Failure
# 7503            0.217416        Overstrain Failure
#
# [7504 rows x 32 columns]

# %%
print(df['Condition_Score'].describe())

sns.histplot(df['Condition_Score'], bins=30, kde=True)
plt.title('Condition Score Distribution')
plt.show()
# Out:
# count    7504.000000
# mean        0.413262
# std         0.155294
# min         0.057581
# 25%         0.306638
# 50%         0.401248
# 75%         0.506129
# max         1.095487
# Name: Condition_Score, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
lb1=LabelEncoder()
df['Failure_Type']=lb.fit_transform(df['Failure_Type'])
# df['Priority']=lb1.fit_transform(df['Priority'])
print(lb.classes_)
# print(lb.inverse_transform([0,1,2,3]))
# print(lb1.classes_)
# print(lb1.inverse_transform([0,1,2]))
# Out:
# ['Heat Dissipation Failure' 'No Failure' 'Overstrain Failure'
#  'Power Failure']

# %%
from sklearn.model_selection import train_test_split
df.drop(columns=['Priority','GPS_Longitude','GPS_Latitude','GPS_Bearing','GPS_Altitude','Maintenance_flag'],axis=1,inplace=True)
x=df.drop(columns=['Failure_Type'])
y=df['Failure_Type']

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
plt.draw()

# %%
df.columns
# Out:
# Index(['Vehicle_speed_sensor', 'Vibration', 'Engine_Load',
#        'Engine_Coolant_Temp', 'Intake_Manifold_Pressure', 'Engine_RPM',
#        'Speed_OBD', 'Intake_Air_Temp', 'Mass_Air_Flow_Rate',
#        'Throttle_Pos_Manifold', 'Voltage_Control_Module', 'Ambient_air_temp',
#        'Accel_Pedal_Pos_D', 'Engine_Oil_Temp', 'Speed_GPS',
#        'Turbo_Boost_And_Vcm_Gauge', 'Trip_Distance', 'Litres_Per_100km_Inst',
#        'Accel_Ssor_Total', 'CO2_in_g_per_km_Inst', 'Trip_Time_journey',
#        'Condition_Score', 'Overstrain_Risk', 'Heat_Dissipation_Risk',
#        'Power_Failure_Risk', 'Failure_Type'],
#       dtype='object')

# %%
xtrain,xtest, ytrain, ytest=train_test_split(x,y,test_size=0.2,random_state=42)
xtrain,xval,ytrain,yval=train_test_split(xtrain, ytrain, test_size=0.1,random_state=42)
train = lgb.Dataset(xtrain,label=ytrain)
val=lgb.Dataset(xval,label=yval)

# %%
params = {
    'objective': 'multiclass',
    'num_class': len(lb.classes_),  
    'boosting_type': 'gbdt',
    'metric': 'multi_logloss',
    'learning_rate': 0.05,
    'max_depth': 6,
    'num_leaves': 31,
    'min_data_in_leaf': 20,
    'lambda_l1': 0.1,
    'lambda_l2': 0.1,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': -1,
    'seed': 42
}
params['is_unbalance'] = True

# %%
early_stopping_callback = lgb.early_stopping(stopping_rounds=30)
verbose_eval_callback = lgb.log_evaluation(period=10)

lgb_model = lgb.train(
    params,
    train,
    num_boost_round=350,  
    valid_sets=[train, val],
    callbacks=[early_stopping_callback, verbose_eval_callback]
)
# Out:
# Training until validation scores don't improve for 30 rounds
# [10]	training's multi_logloss: 0.391055	valid_1's multi_logloss: 0.427553
# [20]	training's multi_logloss: 0.202588	valid_1's multi_logloss: 0.240654
# [30]	training's multi_logloss: 0.10836	valid_1's multi_logloss: 0.146572
# [40]	training's multi_logloss: 0.0634013	valid_1's multi_logloss: 0.102116
# [50]	training's multi_logloss: 0.0409294	valid_1's multi_logloss: 0.0821249
# [60]	training's multi_logloss: 0.0284401	valid_1's multi_logloss: 0.0699275
# [70]	training's multi_logloss: 0.0205259	valid_1's multi_logloss: 0.0628289
# [80]	training's multi_logloss: 0.0158532	valid_1's multi_logloss: 0.0579118
# [90]	training's multi_logloss: 0.0124121	valid_1's multi_logloss: 0.0556062
# [100]	training's multi_logloss: 0.00995627	valid_1's multi_logloss: 0.0531441
# [110]	training's multi_logloss: 0.00831982	valid_1's multi_logloss: 0.0509169
# [120]	training's multi_logloss: 0.00697499	valid_1's multi_logloss: 0.0499293
# [130]	training's multi_logloss: 0.00583953	valid_1's multi_logloss: 0.0489536
# [140]	training's multi_logloss: 0.00501542	valid_1's multi_logloss: 0.0480831
# [150]	training's multi_logloss: 0.00432355	valid_1's multi_logloss: 0.0480471
# [160]	training's multi_logloss: 0.00380742	valid_1's multi_logloss: 0.0476969
# [170]	training's multi_logloss: 0.00330385	valid_1's multi_logloss: 0.0469133
# [180]	training's multi_logloss: 0.00290306	valid_1's multi_logloss: 0.0472055
# [190]	training's multi_logloss: 0.00259345	valid_1's multi_logloss: 0.0477264
# Early stopping, best iteration is:
# [169]	training's multi_logloss: 0.00335173	valid_1's multi_logloss: 0.0468931

# %%
predprob = lgb_model.predict(xtest)

pred = [np.argmax(prob) for prob in predprob]
from sklearn.metrics import accuracy_score, classification_report
print(accuracy_score(ytest, pred))
# Out:
# 0.9893404397068621

# %%
print(classification_report(ytest,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       889
#            1       1.00      1.00      1.00       385
#            2       0.97      0.97      0.97       221
#            3       1.00      0.17      0.29         6
#
#     accuracy                           0.99      1501
#    macro avg       0.99      0.78      0.81      1501
# weighted avg       0.99      0.99      0.99      1501

# %%
def get_user_input():
    user_records = []
    while True:
        print("\nEnter vehicle parameters:")
        engine_load = float(input("Enter Engine Load: "))
        engine_rpm = float(input("Enter Engine RPM: "))
        engine_coolant_temp = float(input("Enter Engine Coolant Temperature: "))
        trip_distance = float(input("Enter Trip Distance: "))
        trip_time_journey = float(input("Enter Trip Time Journey: "))
        vibration = float(input("Enter Vibration: "))
        mass_air_flow_rate = float(input("Enter Mass Air Flow Rate: "))
        engine_oil_temp = float(input("Enter Engine Oil Temperature: "))
        throttle_pos_manifold = float(input("Enter Throttle Position: "))
        accel_ssor_total = float(input("Enter Acceleration Sensor Total: "))
        turbo_boost_vcm = float(input("Enter Turbo Boost & VCM Gauge: "))
        vehicle_speed_sensor = float(input("Enter Vehicle Speed Sensor: "))
        intake_manifold_pressure = float(input("Enter Intake Manifold Pressure: "))
        speed_obd = float(input("Enter Speed OBD: "))
        intake_air_temp = float(input("Enter Intake Air Temperature: "))
        voltage_control_module = float(input("Enter Voltage Control Module: "))
        ambient_air_temp = float(input("Enter Ambient Air Temperature: "))
        accel_pedal_pos_d = float(input("Enter Acceleration Pedal Position D: "))
        speed_gps = float(input("Enter Speed GPS: "))
        litres_per_100km_inst = float(input("Enter Litres Per 100km Inst: "))
        co2_in_g_per_km_inst = float(input("Enter CO2 in g/km Inst: "))

        user_records.append({
            'Engine_Load': engine_load,
            'Engine_RPM': engine_rpm,
            'Engine_Coolant_Temp': engine_coolant_temp,
            'Vibration': vibration,
            'Mass_Air_Flow_Rate': mass_air_flow_rate,
            'Engine_Oil_Temp': engine_oil_temp,
            'Throttle_Pos_Manifold': throttle_pos_manifold,
            'Accel_Ssor_Total': accel_ssor_total,
            'Trip_Distance': trip_distance,
            'Trip_Time_journey': trip_time_journey,
            'Turbo_Boost_And_Vcm_Gauge': turbo_boost_vcm,
            'Vehicle_Speed_Sensor': vehicle_speed_sensor,
            'Intake_Manifold_Pressure': intake_manifold_pressure,
            'Speed_OBD': speed_obd,
            'Intake_Air_Temp': intake_air_temp,
            'Voltage_Control_Module': voltage_control_module,
            'Ambient_Air_Temp': ambient_air_temp,
            'Accel_Pedal_Pos_D': accel_pedal_pos_d,
            'Speed_GPS': speed_gps,
            'Litres_Per_100km_Inst': litres_per_100km_inst,
            'CO2_in_g_per_km_Inst': co2_in_g_per_km_inst
        })

        add = input("Do you want to enter another instance? (yes/no): ").lower()
        if add != 'yes':
            break

    user_df = pd.DataFrame(user_records)

    user_df[features_to_normalize] = scaler.transform(user_df[features_to_normalize])

    condition_score = calculate_condition_score(user_df)
    user_df['Condition_Score'] = condition_score
    calc_risk(user_df)

    return user_df

# %%
import numpy as np

def predict_failure():
    user_df = get_user_input()

    print("\nUser DataFrame:")
    print(user_df.head())
    # feature_names = lgb_model.feature_name()
    # user_df = user_df[feature_names] 
    prediction = lgb_model.predict(user_df)

    predicted_class_indices = np.argmax(prediction, axis=1)

    failure_types = lb.inverse_transform(predicted_class_indices.reshape(-1,))

    user_df["Predicted_Failure_Type"] = failure_types

    # print("\nFinal Predicted Failures:")
    # print(user_df[["Condition_Score", "Predicted_Failure_Type"]])

    return user_df

predicted_df = predict_failure()
predicted_df = predicted_df.sort_values(by="Condition_Score", ascending=False)
print(predicted_df)
# Out:
# Enter vehicle parameters:
# Enter Engine Load:  1234
# Enter Engine RPM:  2343
# Enter Engine Coolant Temperature:  54
# Enter Trip Distance:  5656
# Enter Trip Time Journey:  234
# Enter Vibration:  234234
# Enter Mass Air Flow Rate:  566
# Enter Engine Oil Temperature:  7676
# Enter Throttle Position:  232
# Enter Acceleration Sensor Total:  244
# Enter Turbo Boost & VCM Gauge:  66
# Enter Vehicle Speed Sensor:  333
# Enter Intake Manifold Pressure:  354
# Enter Speed OBD:  67
# Enter Intake Air Temperature:  343
# Enter Voltage Control Module:  546
# Enter Ambient Air Temperature:  999
# Enter Acceleration Pedal Position D:  99
# Enter Speed GPS:  998
# Enter Litres Per 100km Inst:  777
# Enter CO2 in g/km Inst:  1
# Do you want to enter another instance? (yes/no):  yes
# Enter vehicle parameters:
# Enter Engine Load:  123
# Enter Engine RPM:  234
# Enter Engine Coolant Temperature:  345
# Enter Trip Distance:  567
# Enter Trip Time Journey:  789
# Enter Vibration:  890
# Enter Mass Air Flow Rate:  111
# Enter Engine Oil Temperature:  23
# Enter Throttle Position:  45
# Enter Acceleration Sensor Total:  667
# Enter Turbo Boost & VCM Gauge:  321
# Enter Vehicle Speed Sensor:  345
# Enter Intake Manifold Pressure:  666
# Enter Speed OBD:  1
# Enter Intake Air Temperature:  234
# Enter Voltage Control Module:  2
# Enter Ambient Air Temperature:  8
# Enter Acceleration Pedal Position D:  77
# Enter Speed GPS:  66
# Enter Litres Per 100km Inst:  45
# Enter CO2 in g/km Inst:  1
# Do you want to enter another instance? (yes/no):  n
# User DataFrame:
#    Engine_Load  Engine_RPM  Engine_Coolant_Temp     Vibration  \
# 0    12.433597    0.868257            -1.666667  22614.607789
# 1     1.235771   -0.225622            17.733333     62.743934
#
#    Mass_Air_Flow_Rate  Engine_Oil_Temp  Throttle_Pos_Manifold  \
# 0            4.999018       542.714286               3.827941
# 1            0.938331        -3.928571               0.321691
#
#    Accel_Ssor_Total  Trip_Distance  Trip_Time_journey  ...  \
# 0        204.769963      31.394869          -0.368812  ...
# 1        558.694213       2.453709          -0.302289  ...
#
#    Voltage_Control_Module  Ambient_Air_Temp  Accel_Pedal_Pos_D  Speed_GPS  \
# 0                   546.0             999.0               99.0      998.0
# 1                     2.0               8.0               77.0       66.0
#
#    Litres_Per_100km_Inst  CO2_in_g_per_km_Inst  Condition_Score  \
# 0                  777.0                   1.0       117.868846
# 1                   45.0                   1.0         4.121512
#
#    Overstrain_Risk  Heat_Dissipation_Risk  Power_Failure_Risk
# 0         6.650927             324.961905            3.970274
# 1         0.505074               4.736190            7.685561
#
# [2 rows x 25 columns]
#    Engine_Load  Engine_RPM  Engine_Coolant_Temp     Vibration  \
# 0    12.433597    0.868257            -1.666667  22614.607789
# 1     1.235771   -0.225622            17.733333     62.743934
#
#    Mass_Air_Flow_Rate  Engine_Oil_Temp  Throttle_Pos_Manifold  \
# 0            4.999018       542.714286               3.827941
# 1            0.938331        -3.928571               0.321691
#
#    Accel_Ssor_Total  Trip_Distance  Trip_Time_journey  ...  Ambient_Air_Temp  \
# 0        204.769963      31.394869          -0.368812  ...             999.0
# 1        558.694213       2.453709          -0.302289  ...               8.0
#
#    Accel_Pedal_Pos_D  Speed_GPS  Litres_Per_100km_Inst  CO2_in_g_per_km_Inst  \
# 0               99.0      998.0                  777.0                   1.0
# 1               77.0       66.0                   45.0                   1.0
#
#    Condition_Score  Overstrain_Risk  Heat_Dissipation_Risk  \
# 0       117.868846         6.650927             324.961905
# 1         4.121512         0.505074               4.736190
#
#    Power_Failure_Risk    Predicted_Failure_Type
# 0            3.970274  Heat Dissipation Failure
# 1            7.685561  Heat Dissipation Failure
#
# [2 rows x 26 columns]

# %%
import pickle

with open('lgbm.pkl', 'wb') as f:
    pickle.dump(lgb_model, f)
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
